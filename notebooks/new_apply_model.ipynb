// %%
import org.apache.spark.sql.types.{StructType, StringType,StructField, IntegerType, LongType}
import org.apache.spark.ml.{Pipeline, PipelineModel}
import org.apache.spark.sql.functions._
import org.apache.spark.sql.DataFrame

// %%
println(s"Current spark version is ${spark.version}")
// Out:
// Current spark version is 2.4.4

// %%
val inputStreamPath = "/home/jovyan/data/events-stream"
val modelPath = "/home/jovyan/models/spark-ml-model"
val model = PipelineModel.load(modelPath)

val dataSchema = new StructType()
    .add("tweet", StringType)
val inputDF = spark
    .readStream
    .schema(dataSchema)
    .option("maxFilesPerTrigger", 1)
    .json(inputStreamPath)
// Out:
// inputStreamPath = /home/jovyan/data/events-stream
// modelPath = /home/jovyan/models/spark-ml-model
// model = pipeline_0712a1d840e0
// dataSchema = StructType(StructField(tweet,StringType,true))
// inputDF = [tweet: string]
// [tweet: string]

// %%
import java.time.Instant
val getProbability = udf((prediction: org.apache.spark.ml.linalg.Vector) => prediction(1))
val getTimestamp = udf(() => Instant.now.getEpochSecond )
val dataSchema = new StructType()
    .add("tweet", StringType)
    .add("prediction", IntegerType)
    .add("clean_probability", LongType)
    .add("TIMESTAMP", LongType)

var oldDF = Seq.empty[(String, Int, Long, Long)].toDF("tweet", "prediction", "clean_probability", "TIMESTAMP")

inputDF.writeStream.foreachBatch { (batchDF: DataFrame, batchId: Long) =>
    
    val predictionsDF = model.transform(batchDF)
    val TenMins = getTimestamp() - 10
    val DF = predictionsDF.select($"tweet", $"prediction", getProbability($"probability").alias("clean_probability"), getTimestamp().alias("TIMESTAMP"))
        
    oldDF = oldDF.union(DF)
    DF.show(100)
    println(oldDF.count())  
    oldDF.filter($"TIMESTAMP" >= TenMins).groupBy("prediction").count().show()
}.start()
// Out:
// +--------------------+----------+-------------------+----------+
// |               tweet|prediction|  clean_probability| TIMESTAMP|
// +--------------------+----------+-------------------+----------+
// |Revising latin ve...|       1.0| 0.5063874178122819|1583408179|
// |My Dad had a stro...|       1.0| 0.5272337637446153|1583408179|
// |@FSOnline Do you ...|       0.0|0.44711200702403436|1583408179|
// |Golly it's a prop...|       0.0|0.45750550378135324|1583408179|
// |oy NK DRAMA KIDS!...|       0.0| 0.4720856221457628|1583408179|
// |       At workkk... |       1.0| 0.5335873473819716|1583408179|
// |callin a cab. wor...|       1.0| 0.5335873473819716|1583408179|
// |BNP get an MEP? I...|       1.0| 0.5335873473819716|1583408179|
// |@Bionic1 we need ...|       1.0| 0.5335873473819716|1583408179|
// |@billbeckett i lo...|       0.0| 0.4045377706885748|1583408179|
// |feeling very happ...|       0.0|  0.499594950360727|1583408179|
// |@Pippi43 Hey!  Gl...|       1.0| 0.5615444265398342|1583408179|
// |listening to rent...|       0.0|0.45825571625270933|1583408179|
// |      2 Grand!!!!!! |       1.0| 0.5239134235580475|1583408179|
// |Heey! Eu tive um ...|       1.0| 0.5087205519219935|1583408179|
// |would like some p...|       1.0| 0.5335873473819716|1583408179|
// |@Jasmine__Murray ...|       1.0| 0.5335873473819716|1583408179|
// |    Hello Tweeties! |       1.0| 0.5335873473819716|1583408179|
// |goin to c britney...|       1.0| 0.5233082784595477|1583408179|
// +--------------------+----------+-------------------+----------+
//
// 19
// getProbability = UserDefinedFunction(<function1>,DoubleType,Some(List(org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7)))
// getTimestamp = UserDefinedFunction(<function0>,LongType,Some(List()))
// dataSchema = StructType(StructField(tweet,StringType,true), StructField(prediction,IntegerType,true), StructField(clean_probability,LongType,true), StructField(TIMESTAMP,LongType,true))
// oldDF = [tweet: string, prediction: int ... 2 more fields]
// org.apache.spark.sql.execution.streaming.StreamingQueryWrapper@4107d264
// +----------+-----+
// |prediction|count|
// +----------+-----+
// |       0.0|    6|
// |       1.0|   13|
// +----------+-----+
//
// +--------------------+----------+-------------------+----------+
// |               tweet|prediction|  clean_probability| TIMESTAMP|
// +--------------------+----------+-------------------+----------+
// |@NotoriousTIMP bl...|       0.0| 0.4750251093358478|1583408183|
// |@KILA21 ok I saww...|       0.0| 0.4348257203107105|1583408183|
// |Bloody bollocking...|       1.0| 0.5287849050889146|1583408183|
// |@maynaseric Ya, I...|       0.0|0.45115344186973616|1583408183|
// |Life is so differ...|       0.0|  0.389210498496237|1583408183|
// |@Anthonyyyy i can...|       0.0|0.45825571625270933|1583408183|
// |ohh its so clod a...|       0.0|   0.43778405489319|1583408183|
// |@al_ice I was act...|       0.0| 0.4469177594859313|1583408183|
// |study study study...|       1.0| 0.5335873473819716|1583408183|
// |Finally got her r...|       1.0| 0.5335873473819716|1583408183|
// |@Mr_PaulEvans  ba...|       1.0| 0.5188107671672452|1583408183|
// |Our Latest Newsle...|       1.0| 0.5335873473819716|1583408183|
// |got a good nights...|       1.0| 0.5509558907907888|1583408183|
// |@Fixeche are you ...|       1.0| 0.5734928397511115|1583408183|
// +--------------------+----------+-------------------+----------+
//
// 33
// +----------+-----+
// |prediction|count|
// +----------+-----+
// |       0.0|   13|
// |       1.0|   20|
// +----------+-----+
//
// +--------------------+----------+-------------------+----------+
// |               tweet|prediction|  clean_probability| TIMESTAMP|
// +--------------------+----------+-------------------+----------+
// |@ScaredyCat no wo...|       1.0| 0.5063874178122819|1583408186|
// |@GetBillG oh yeah...|       1.0| 0.5335873473819716|1583408186|
// |What a busy day, ...|       1.0| 0.5335873473819716|1583408186|
// |@Chriscarroll50 t...|       1.0|  0.557309474428145|1583408186|
// |doing my hmwrk --...|       0.0|0.49962473323683954|1583408186|
// |@xt0rrent i think...|       0.0|0.45825571625270933|1583408186|
// |i'm up wayyyyyy t...|       1.0| 0.5217571371152485|1583408186|
// |im gonna leave th...|       1.0| 0.5448508590864234|1583408186|
// |oh joys, my compr...|       1.0| 0.5272337637446153|1583408186|
// |Yes! Stacked 122 ...|       1.0| 0.5335873473819716|1583408186|
// |     @anneyy thanks |       1.0| 0.5604590803002939|1583408186|
// |@khali_blache Whe...|       0.0|0.45115344186973616|1583408186|
// |@dafferss ah righ...|       1.0| 0.5176715184332398|1583408186|
// |@monashand That's...|       1.0| 0.5335873473819716|1583408186|
// |loves being up so...|       0.0| 0.4935978599832175|1583408186|
// |http://twitpic.co...|       1.0| 0.5351384887262708|1583408186|
// |@quintosential al...|       1.0| 0.5448508590864234|1583408186|
// |for all the stalk...|       1.0| 0.5037975982698226|1583408186|
// |@Dannymcfly Hi Da...|       1.0| 0.5952942350320158|1583408186|
// |@NiteshNitesh - h...|       1.0| 0.5335873473819716|1583408204|
// |@rashmi I see you...|       0.0|0.45825571625270933|1583408204|
// |@runkeeper  need ...|       0.0|0.45825571625270933|1583408204|
// |waiting for dom t...|       0.0|0.45115344186973616|1583408204|
// |@crystalgmurphy A...|       1.0| 0.5335873473819716|1583408204|
// |@Stuenva Planting...|       1.0| 0.5604590803002939|1583408204|
// |Lose Urself - Fam...|       1.0| 0.5335873473819716|1583408204|
// |       Good morning |       1.0|  0.557309474428145|1583408204|
// +--------------------+----------+-------------------+----------+
//
// 185
// +----------+-----+
// |prediction|count|
// +----------+-----+
// |       0.0|   60|
// |       1.0|  125|
// +----------+-----+
//
// +--------------------+----------+-------------------+----------+
// |               tweet|prediction|  clean_probability| TIMESTAMP|
// +--------------------+----------+-------------------+----------+
// |I don't wanna get...|       0.0|0.45825571625270933|1583408208|
// |hates being sick!...|       1.0| 0.5335873473819716|1583408208|
// |@YourFavoritePJ w...|       0.0|0.45115344186973616|1583408208|
// |@VidaMapatis i wa...|       0.0| 0.4348257203107105|1583408208|
// |@StaciBennett No ...|       1.0| 0.5063874178122819|1583408208|
// |@baffled thatnks ...|       0.0| 0.4656997885069677|1583408208|
// |Marriage is a pun...|       1.0| 0.5351384887262708|1583408208|
// +--------------------+----------+-------------------+----------+
//
// 192
// +----------+-----+
// |prediction|count|
// +----------+-----+
// |       0.0|   64|
// |       1.0|  128|
// +----------+-----+
//
// +--------------------+----------+-------------------+----------+
// |               tweet|prediction|  clean_probability| TIMESTAMP|
// +--------------------+----------+-------------------+----------+
// |exams...are...kil...|       1.0| 0.5055483373715989|1583408211|
// |@truantrebellion ...|       1.0| 0.5053722374163818|1583408211|
// |         Got a cold |       1.0|   0.51760702134242|1583408211|
// |Hoping Megan is h...|       1.0|  0.557309474428145|1583408211|
// |@chris_kovach   H...|       0.0|0.42848061843697016|1583408211|
// |Ugh my neck is ab...|       1.0| 0.5272337637446153|1583408211|
// |I don't want to g...|       0.0| 0.4419279946936837|1583408211|
// |Stupid bus doors ...|       1.0| 0.5335873473819716|1583408211|
// |Seem like I ate t...|       0.0|0.45825571625270933|1583408211|
// |@Britty0314   the...|       1.0| 0.5530666516074562|1583408211|
// |Cant talk, swallo...|       1.0| 0.5335873473819716|1583408211|
// |@zombean1138 YAY!...|       1.0| 0.5465990045234067|1583408211|
// |@pinpoint_uk   (p...|       1.0| 0.5335873473819716|1583408211|
// |  waiting for zaccy |       1.0| 0.5335873473819716|1583408211|
// |We should have a ...|       1.0| 0.5453610612168676|1583408211|
// |@Sky_1995 Haha! I...|       0.0| 0.4750251093358478|1583408211|
// |Oh &amp; thank yo...|       1.0| 0.5567801309527913|1583408211|
// +--------------------+----------+-------------------+----------+
//
// 209
// +----------+-----+
// |prediction|count|
// +----------+-----+
// |       0.0|   68|
// |       1.0|  141|
// +----------+-----+
//
// +--------------------+----------+-------------------+----------+
// |               tweet|prediction|  clean_probability| TIMESTAMP|
// +--------------------+----------+-------------------+----------+
// |why is nobody twe...|       0.0| 0.4726380129615701|1583408215|
// |I am in Santa Cru...|       0.0| 0.4469177594859313|1583408215|
// |Is at home bored ...|       1.0| 0.5272337637446153|1583408215|
// |getting ready to ...|       0.0| 0.4222803302688833|1583408215|
// |@msmanya Thats no...|       0.0| 0.4272011584805133|1583408215|
// |@tesslee thanks, ...|       0.0|0.42867094388526433|1583408215|
// |is going to bed. ...|       1.0| 0.5351384887262708|1583408215|
// |@iantalbot Oh abo...|       1.0|  0.549770712704938|1583408215|
// |Good night, galax...|       1.0|  0.557309474428145|1583408215|
// |Happy 1,000th twe...|       1.0| 0.5363643410012595|1583408215|
// |@artistacemoney I...|       0.0|0.45115344186973616|1583408215|
// |Talkin to my bby ...|       0.0|0.42867094388526433|1583408215|
// +--------------------+----------+-------------------+----------+
// 221

// %%
spark.stop()
// Out:
// lastException: Throwable = null
// lastException: Throwable = null
// error:
//   unrecoverable error
//      while compiling: <console>
//         during phase: erasure
//      library version: version 2.11.12
//     compiler version: version 2.11.12
//   reconstructed args: -classpath file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/sunjce_provider.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/localedata.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/sunpkcs11.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/sunec.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/icedtea-sound.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/nashorn.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/dnsns.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/cldrdata.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/jaccess.jar:file:/usr/lib/jvm/java-8-openjdk-amd64/jre/lib/ext/zipfs.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/conf/:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/commons-math3-3.4.1.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/commons-lang-2.6.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/hadoop-client-2.7.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/JavaEWAH-0.3.2.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/xmlenc-0.52.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jersey-container-servlet-2.22.2.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/orc-shims-1.5.5.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/json4s-jackson_2.11-3.5.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/spark-kubernetes_2.11-2.4.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/paranamer-2.8.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/metrics-core-3.1.5.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/arrow-format-0.10.0.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/api-asn1-api-1.0.0-M20.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jackson-core-2.6.7.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/curator-client-2.7.1.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/json4s-ast_2.11-3.5.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/spark-repl_2.11-2.4.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/aircompressor-0.10.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/hive-exec-1.2.1.spark2.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/spark-network-common_2.11-2.4.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/chill_2.11-0.9.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/datanucleus-api-jdo-3.2.6.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/commons-digester-1.8.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jackson-module-scala_2.11-2.6.7.1.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/metrics-graphite-3.1.5.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jackson-jaxrs-1.9.13.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/hadoop-yarn-client-2.7.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/hive-metastore-1.2.1.spark2.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/kubernetes-model-common-4.1.2.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jodd-core-3.5.2.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jsp-api-2.1.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/curator-recipes-2.7.1.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jackson-core-asl-1.9.13.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/libfb303-0.9.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/hadoop-mapreduce-client-shuffle-2.7.3.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/spark-streaming_2.11-2.4.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/bonecp-0.8.0.RELEASE.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/parquet-encoding-1.10.1.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/spark-mesos_2.11-2.4.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/parquet-hadoop-bundle-1.6.0.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/spark-graphx_2.11-2.4.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/jackson-module-jaxb-annotations-2.6.7.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/gson-2.2.4.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/jars/api-util-1.0.0-M20.jar:file:/usr/local/spark-2.4.4-bin-hadoop2.7/ja ...
//   last tree to typer: This(class $iw)
//        tree position: line 35 of <console>
//             tree tpe: type
//               symbol: class $iw
//    symbol definition: class $iw extends Serializable (a ClassSymbol)
//       symbol package: $line42
//        symbol owners: class $iw -> class $iw -> class $iw -> class $iw -> class $iw -> class $iw -> class $iw -> class $iw -> class $read
//            call site: class $iw in package $line42
// <Cannot read source file>
// lastException: Throwable = null
